# %% [markdown]
# -- CLEANING bollywood_movies.sqlite FILE

# %% [markdown]
# - importing necessary modules

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# -- path for my data file

# %%
folder="data"
subfolder="movies_data"
filename="bollywood_movies.sqlite"
path=f'{folder}/{subfolder}/{filename}'
path
# Out:
# 'data/movies_data/bollywood_movies.sqlite'

# %% [markdown]
# -- connect to sqlite DB

# %%
conn = sqlite3.connect(path)

# %% [markdown]
# - giving a query to check table and read data from file usiing that given query

# %%
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(tables_query, conn)
tables
# Out:
#      name
# 0  Movies

# %% [markdown]
# -- giving query to select all data from table "Movies"

# %%
query = "SELECT * FROM Movies"
df = pd.read_sql(query, conn)
df.head()
# Out:
#    index MovieID                         Title            Director  \
# 0      0  MOV001                        Lagaan  Ashutosh Gowariker
# 1      1  MOV002   Kabhi Khushi Kabhie Gham...         Karan Johar
# 2      2  MOV003  M.S. Dhoni: The Untold Story       Neeraj Pandey
# 3      3  MOV004   Baahubali 2: The Conclusion     S. S. Rajamouli
# 4      4  MOV005               Chennai Express        Rohit Shetty
#
#                        Genre  ReleaseYear  Budget (Crores)  \
# 0                       None         2001              NaN
# 1               Family Drama         2001             50.0
# 2  Biographical Sports Drama         2016              NaN
# 3        Epic Fantasy Action         2017            250.0
# 4              Action Comedy         2013              NaN
#
#    BoxOffice (Crores)  Rating  Duration (minutes)             LeadActor  \
# 0               100.0     8.1                 224            Aamir Khan
# 1               100.0     7.9                 210        Shah Rukh Khan
# 2               215.0     7.9                 184  Sushant Singh Rajput
# 3              1810.0     8.2                 171               Prabhas
# 4               423.0     6.4                 141        Shah Rukh Khan
#
#         LeadActress Language           ProductionCompany
# 0       Gracy Singh    Hindi      Aamir Khan Productions
# 1             Kajol    Hindi          Dharma Productions
# 2      Kiara Advani    Hindi            Fox Star Studios
# 3    Anushka Shetty   Telugu            Arka Media Works
# 4  Deepika Padukone    Hindi  Red Chillies Entertainment

# %% [markdown]
# -- close connnectiion after storing the data in df for avoiding memory leakage

# %%
conn.close
# Out:
# <function Connection.close()>

# %% [markdown]
# -- Now we have our data in dataframe, we can check for anomalies and clean it

# %%
df.columns
# Out:
# Index(['index', 'MovieID', 'Title', 'Director', 'Genre', 'ReleaseYear',
#        'Budget (Crores)', 'BoxOffice (Crores)', 'Rating', 'Duration (minutes)',
#        'LeadActor', 'LeadActress', 'Language', 'ProductionCompany'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               55 non-null     int64
#  1   MovieID             55 non-null     object
#  2   Title               55 non-null     object
#  3   Director            55 non-null     object
#  4   Genre               54 non-null     object
#  5   ReleaseYear         55 non-null     int64
#  6   Budget (Crores)     43 non-null     float64
#  7   BoxOffice (Crores)  46 non-null     float64
#  8   Rating              55 non-null     float64
#  9   Duration (minutes)  55 non-null     int64
#  10  LeadActor           55 non-null     object
#  11  LeadActress         55 non-null     object
#  12  Language            55 non-null     object
#  13  ProductionCompany   55 non-null     object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 6.1+ KB

# %% [markdown]
# -- missing data in Genre column

# %%
df.Genre.unique()
# Out:
# array([None, 'Family Drama', 'Biographical Sports Drama',
#        'Epic Fantasy Action', 'Action Comedy', 'Drama', 'Action Thriller',
#        'Satirical Science Fiction Comedy', 'Science Fiction Action',
#        'Historical Romance', 'Romance', 'Superhero Science Fiction',
#        'Action-Adventure', 'Musical Drama', 'Historical Action',
#        'Action Drama', 'Superhero', 'Sports Drama', 'Sports Action',
#        'Romantic Comedy', 'Romantic Drama', 'Thriller',
#        'Psychological Thriller', 'Historical Sports Drama',
#        'Comedy Drama', 'Biographical Drama', 'Satirical Comedy'],
#       dtype=object)

# %% [markdown]
# -- we can fill missing value with most common genre

# %%
df["Genre"].mode()[0]
# Out:
# 'Action Thriller'

# %% [markdown]
# -- checking the other columns like Title for row with none value in genre

# %%
df[df["Genre"].isna()]
# Out:
#    index MovieID   Title            Director Genre  ReleaseYear  \
# 0      0  MOV001  Lagaan  Ashutosh Gowariker  None         2001
#
#    Budget (Crores)  BoxOffice (Crores)  Rating  Duration (minutes)  \
# 0              NaN               100.0     8.1                 224
#
#     LeadActor  LeadActress Language       ProductionCompany
# 0  Aamir Khan  Gracy Singh    Hindi  Aamir Khan Productions

# %% [markdown]
# -- Movie with none value of genre is Lagaan , Most frequent genre is Action thriller which isn't appropriate genre for this movie So I am filling this with correct( more appropriate genre ) value instead

# %%
df["Genre"]=df["Genre"].fillna("Historical Sports Drama")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               55 non-null     int64
#  1   MovieID             55 non-null     object
#  2   Title               55 non-null     object
#  3   Director            55 non-null     object
#  4   Genre               55 non-null     object
#  5   ReleaseYear         55 non-null     int64
#  6   Budget (Crores)     43 non-null     float64
#  7   BoxOffice (Crores)  46 non-null     float64
#  8   Rating              55 non-null     float64
#  9   Duration (minutes)  55 non-null     int64
#  10  LeadActor           55 non-null     object
#  11  LeadActress         55 non-null     object
#  12  Language            55 non-null     object
#  13  ProductionCompany   55 non-null     object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 6.1+ KB

# %%
df[df['Budget (Crores)'].isna()]
# Out:
#     index MovieID                         Title                     Director  \
# 0       0  MOV001                        Lagaan           Ashutosh Gowariker
# 2       2  MOV003  M.S. Dhoni: The Untold Story                Neeraj Pandey
# 4       4  MOV005               Chennai Express                 Rohit Shetty
# 7       7  MOV008                Sarkar (Tamil)             A. R. Murugadoss
# 11     11  MOV012   Dilwale Dulhania Le Jayenge                Aditya Chopra
# 23     23  MOV024    Avengers: Endgame (Dubbed)  Anthony Russo, Joseph Russo
# 32     32  MOV033           96 (Kannada Dubbed)                 C. Premkumar
# 34     34  MOV035            Dabangg 3 (Dubbed)                  Prabhu Deva
# 36     36  MOV037      Shylock (Kannada Dubbed)                 Ajai Vasudev
# 37     37  MOV038         Love Aaj Kal (Dubbed)                   Imtiaz Ali
# 38     38  MOV039     Forensic (Kannada Dubbed)        Akhil Paul, Anas Khan
# 39     39  MOV040       Trance (Kannada Dubbed)                Anwar Rasheed
#
#                         Genre  ReleaseYear  Budget (Crores)  \
# 0     Historical Sports Drama         2001              NaN
# 2   Biographical Sports Drama         2016              NaN
# 4               Action Comedy         2013              NaN
# 7             Action Thriller         2005              NaN
# 11                    Romance         1995              NaN
# 23                  Superhero         2019              NaN
# 32             Romantic Drama         2019              NaN
# 34              Action Comedy         2019              NaN
# 36            Action Thriller         2020              NaN
# 37             Romantic Drama         2020              NaN
# 38                   Thriller         2020              NaN
# 39     Psychological Thriller         2020              NaN
#
#     BoxOffice (Crores)  Rating  Duration (minutes)             LeadActor  \
# 0                100.0     8.1                 224            Aamir Khan
# 2                215.0     7.9                 184  Sushant Singh Rajput
# 4                423.0     6.4                 141        Shah Rukh Khan
# 7                  NaN     7.5                 173                 Vijay
# 11                 NaN     7.7                 189        Shah Rukh Khan
# 23                 NaN     8.4                 181     Robert Downey Jr.
# 32                 NaN     7.9                 158      Vijay Sethupathi
# 34                 NaN     5.8                 159           Salman Khan
# 36                 NaN     6.8                 164             Mammootty
# 37                 NaN     4.4                 141         Kartik Aaryan
# 38                 NaN     6.9                 129         Tovino Thomas
# 39                 NaN     7.1                 162         Fahadh Faasil
#
#            LeadActress                                    Language  \
# 0          Gracy Singh                                       Hindi
# 2         Kiara Advani                                       Hindi
# 4     Deepika Padukone                                       Hindi
# 7       Keerthy Suresh                                       Tamil
# 11               Kajol                                       Hindi
# 23  Scarlett Johansson  English (Dubbed in Telugu, Kannada, Hindi)
# 32              Trisha                 Kannada (Dubbed from Tamil)
# 34      Sonakshi Sinha                  Telugu (Dubbed from Hindi)
# 36            Rajkiran             Kannada (Dubbed from Malayalam)
# 37       Sara Ali Khan                  Telugu (Dubbed from Hindi)
# 38      Mamta Mohandas             Kannada (Dubbed from Malayalam)
# 39       Nazriya Nazim             Kannada (Dubbed from Malayalam)
#
#               ProductionCompany
# 0        Aamir Khan Productions
# 2              Fox Star Studios
# 4    Red Chillies Entertainment
# 7                  Kalaignar TV
# 11               Yash Raj Films
# 23               Marvel Studios
# 32           Madras Enterprises
# 34       S. K. Film Enterprises
# 36             Vrindaavan Films
# 37       Reliance Entertainment
# 38            Evil Eye Pictures
# 39  Dulquer Salmaan Productions

# %% [markdown]
# -- Handling missing values in Budget(Crores) and BoxOffice (Crores) . Since they are numerical columns I'm filling null values with median

# %%
df['Budget (Crores)']=df['Budget (Crores)'].fillna(df["Budget (Crores)"].median())
df['BoxOffice (Crores)']=df['BoxOffice (Crores)'].fillna(df['BoxOffice (Crores)'].median())
cols=['Budget (Crores)','BoxOffice (Crores)']
df[cols]
# Out:
#     Budget (Crores)  BoxOffice (Crores)
# 0              50.0               100.0
# 1              50.0               100.0
# 2              50.0               215.0
# 3             250.0              1810.0
# 4              50.0               423.0
# 5             100.0               325.0
# 6              70.0              2140.0
# 7              50.0               250.0
# 8              85.0               792.0
# 9             550.0               800.0
# 10            120.0               565.0
# 11             50.0               250.0
# 12            115.0               530.0
# 13             85.0               395.0
# 14            150.0               565.0
# 15             60.0               254.0
# 16            300.0               335.0
# 17             40.0               238.0
# 18            150.0               475.0
# 19            150.0               368.0
# 20            180.0               650.0
# 21             50.0               250.0
# 22            200.0               265.0
# 23             50.0               250.0
# 24             20.0                45.0
# 25             30.0                55.0
# 26             10.0               130.0
# 27             20.0                40.0
# 28             15.0                35.0
# 29             10.0                20.0
# 30            300.0               450.0
# 31              5.0                10.0
# 32             50.0               250.0
# 33             75.0               260.0
# 34             50.0               250.0
# 35             20.0                50.0
# 36             50.0               250.0
# 37             50.0               250.0
# 38             50.0               250.0
# 39             50.0               250.0
# 40              4.0                61.0
# 41             50.0               250.0
# 42             25.0                67.0
# 43            180.0               650.0
# 44             35.0               460.0
# 45              1.0                 5.0
# 46             30.0               215.0
# 47             18.0                85.0
# 48              5.0                20.0
# 49             50.0               318.0
# 50              8.0                79.0
# 51            250.0              1810.0
# 52             23.0                69.0
# 53             24.0               216.0
# 54             22.0               221.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               55 non-null     int64
#  1   MovieID             55 non-null     object
#  2   Title               55 non-null     object
#  3   Director            55 non-null     object
#  4   Genre               55 non-null     object
#  5   ReleaseYear         55 non-null     int64
#  6   Budget (Crores)     55 non-null     float64
#  7   BoxOffice (Crores)  55 non-null     float64
#  8   Rating              55 non-null     float64
#  9   Duration (minutes)  55 non-null     int64
#  10  LeadActor           55 non-null     object
#  11  LeadActress         55 non-null     object
#  12  Language            55 non-null     object
#  13  ProductionCompany   55 non-null     object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 6.1+ KB

# %% [markdown]
# -- Our data is cleaned since all columns now contain non null 55 rows and they have correct datatype

# %% [markdown]
# -- Now Store the cleaned df into excel file

# %%
df.to_excel('bollywood_movies.xlsx', index=False)

# %% [markdown]
# -- Getting info for other tables

# %% [markdown]
# - ReleaseYear for MOV049

# %%
df[df['MovieID']=='MOV049']
# Out:
#     index MovieID   Title     Director     Genre  ReleaseYear  \
# 48     48  MOV049  U Turn  Pawan Kumar  Thriller         2016
#
#     Budget (Crores)  BoxOffice (Crores)  Rating  Duration (minutes)  \
# 48              5.0                20.0     7.9                 128
#
#            LeadActor LeadActress Language ProductionCompany
# 48  Shraddha Srinath   Dilip Raj  Kannada   PRK Productions

# %% [markdown]
# -- Budget and BoxOffice info for MOV008, MOV024, MOV033, MOV035, MOV037, MOV038, MOV039, MOV040

# %%
rows=['MOV008', 'MOV024', 'MOV033', 'MOV035', 'MOV037', 'MOV038', 'MOV039', 'MOV040']
df[df['MovieID'].isin(rows)]
# Out:
#     index MovieID                       Title                     Director  \
# 7       7  MOV008              Sarkar (Tamil)             A. R. Murugadoss
# 23     23  MOV024  Avengers: Endgame (Dubbed)  Anthony Russo, Joseph Russo
# 32     32  MOV033         96 (Kannada Dubbed)                 C. Premkumar
# 34     34  MOV035          Dabangg 3 (Dubbed)                  Prabhu Deva
# 36     36  MOV037    Shylock (Kannada Dubbed)                 Ajai Vasudev
# 37     37  MOV038       Love Aaj Kal (Dubbed)                   Imtiaz Ali
# 38     38  MOV039   Forensic (Kannada Dubbed)        Akhil Paul, Anas Khan
# 39     39  MOV040     Trance (Kannada Dubbed)                Anwar Rasheed
#
#                      Genre  ReleaseYear  Budget (Crores)  BoxOffice (Crores)  \
# 7          Action Thriller         2005             50.0               250.0
# 23               Superhero         2019             50.0               250.0
# 32          Romantic Drama         2019             50.0               250.0
# 34           Action Comedy         2019             50.0               250.0
# 36         Action Thriller         2020             50.0               250.0
# 37          Romantic Drama         2020             50.0               250.0
# 38                Thriller         2020             50.0               250.0
# 39  Psychological Thriller         2020             50.0               250.0
#
#     Rating  Duration (minutes)          LeadActor         LeadActress  \
# 7      7.5                 173              Vijay      Keerthy Suresh
# 23     8.4                 181  Robert Downey Jr.  Scarlett Johansson
# 32     7.9                 158   Vijay Sethupathi              Trisha
# 34     5.8                 159        Salman Khan      Sonakshi Sinha
# 36     6.8                 164          Mammootty            Rajkiran
# 37     4.4                 141      Kartik Aaryan       Sara Ali Khan
# 38     6.9                 129      Tovino Thomas      Mamta Mohandas
# 39     7.1                 162      Fahadh Faasil       Nazriya Nazim
#
#                                       Language            ProductionCompany
# 7                                        Tamil                 Kalaignar TV
# 23  English (Dubbed in Telugu, Kannada, Hindi)               Marvel Studios
# 32                 Kannada (Dubbed from Tamil)           Madras Enterprises
# 34                  Telugu (Dubbed from Hindi)       S. K. Film Enterprises
# 36             Kannada (Dubbed from Malayalam)             Vrindaavan Films
# 37                  Telugu (Dubbed from Hindi)       Reliance Entertainment
# 38             Kannada (Dubbed from Malayalam)            Evil Eye Pictures
# 39             Kannada (Dubbed from Malayalam)  Dulquer Salmaan Productions

# %% [markdown]
# -- getting the value of Rating for movie with id MOV031 to fill missing data in indian_movies.csv file

# %%
df[df['MovieID']=='MOV031']
# Out:
#     index MovieID  Title Director            Genre  ReleaseYear  \
# 30     30  MOV031  Saaho  Sujeeth  Action Thriller         2019
#
#     Budget (Crores)  BoxOffice (Crores)  Rating  Duration (minutes) LeadActor  \
# 30            300.0               450.0     6.5                 170   Prabhas
#
#         LeadActress                           Language ProductionCompany
# 30  Shraddha Kapoor  Telugu (Dubbed in Hindi, Kannada)      UV Creations

# %% [markdown]
# -- gettig duration value for movie with id MOV026 to update missing value in indian_movies table

# %%
df[df['MovieID']=='MOV026']
# Out:
#     index MovieID     Title    Director          Genre  ReleaseYear  \
# 25     25  MOV026  Pailwaan  S. Krishna  Sports Action         2019
#
#     Budget (Crores)  BoxOffice (Crores)  Rating  Duration (minutes) LeadActor  \
# 25             30.0                55.0     6.8                 166    Sudeep
#
#         LeadActress Language    ProductionCompany
# 25  Aakanksha Singh  Kannada  RRR Motion Pictures

# %% [markdown]
# -- Finding values for updating the tollywood_movies.xlsx file with correct value wherever there is missing data

# %% [markdown]
# -- getting ReleaseYear for MOV034 and MOV004

# %%
rows=['MOV004','MOV034']
df[df['MovieID'].isin(rows)]
# Out:
#     index MovieID                        Title         Director  \
# 3       3  MOV004  Baahubali 2: The Conclusion  S. S. Rajamouli
# 33     33  MOV034          Sarileru Neekevvaru    Anil Ravipudi
#
#                   Genre  ReleaseYear  Budget (Crores)  BoxOffice (Crores)  \
# 3   Epic Fantasy Action         2017            250.0              1810.0
# 33        Action Comedy         2020             75.0               260.0
#
#     Rating  Duration (minutes)    LeadActor        LeadActress Language  \
# 3      8.2                 171      Prabhas     Anushka Shetty   Telugu
# 33     7.1                 169  Mahesh Babu  Rashmika Mandanna   Telugu
#
#     ProductionCompany
# 3    Arka Media Works
# 33  AK Entertainments

# %% [markdown]
# -- extracting record with movieID MOV027 for updating missing rating value in tollywood_movies data

# %%
df[df['MovieID']=='MOV027']
# Out:
#     index MovieID            Title   Director            Genre  ReleaseYear  \
# 26     26  MOV027  Geetha Govindam  Parasuram  Romantic Comedy         2018
#
#     Budget (Crores)  BoxOffice (Crores)  Rating  Duration (minutes)  \
# 26             10.0               130.0     7.4                 148
#
#             LeadActor        LeadActress Language ProductionCompany
# 26  Vijay Deverakonda  Rashmika Mandanna   Telugu      GA2 Pictures

# %% [markdown]
# -- extracting record with movieID MOV025 for updating missing Duration value in tollywood_movies data

# %%
df[df['MovieID']=='MOV027']
# Out:
#     index MovieID            Title   Director            Genre  ReleaseYear  \
# 26     26  MOV027  Geetha Govindam  Parasuram  Romantic Comedy         2018
#
#     Budget (Crores)  BoxOffice (Crores)  Rating  Duration (minutes)  \
# 26             10.0               130.0     7.4                 148
#
#             LeadActor        LeadActress Language ProductionCompany
# 26  Vijay Deverakonda  Rashmika Mandanna   Telugu      GA2 Pictures

# %% [markdown]
# -- extracting records with movieIDs MOV025, MOV027, MOV029 to fill missing Language values in tollywood_movies table

# %%
rows=['MOV025','MOV027','MOV029']
df[df['MovieID'].isin(rows)]
# Out:
#     index MovieID            Title          Director            Genre  \
# 24     24  MOV025           Jersey  Gowtam Tinnanuri     Sports Drama
# 26     26  MOV027  Geetha Govindam         Parasuram  Romantic Comedy
# 28     28  MOV029     Dear Comrade      Bharat Kamma   Romantic Drama
#
#     ReleaseYear  Budget (Crores)  BoxOffice (Crores)  Rating  \
# 24         2019             20.0                45.0     7.8
# 26         2018             10.0               130.0     7.4
# 28         2019             15.0                35.0     7.1
#
#     Duration (minutes)          LeadActor        LeadActress Language  \
# 24                 160               Nani   Shraddha Srinath   Telugu
# 26                 148  Vijay Deverakonda  Rashmika Mandanna   Telugu
# 28                 170  Vijay Deverakonda  Rashmika Mandanna   Telugu
#
#          ProductionCompany
# 24  Sithara Entertainments
# 26            GA2 Pictures
# 28     Mythri Movie Makers

# %% [markdown]
# -- getting record with moviedID MOV021 to update tollywood_movies table with correct value of ProductionCompany

# %%
df[df['MovieID']=='MOV021']
# Out:
#     index MovieID                    Title         Director  \
# 20     20  MOV021  Bahubali: The Beginning  S. S. Rajamouli
#
#                   Genre  ReleaseYear  Budget (Crores)  BoxOffice (Crores)  \
# 20  Epic Fantasy Action         2015            180.0               650.0
#
#     Rating  Duration (minutes) LeadActor LeadActress Language  \
# 20     8.1                 159   Prabhas   Tamannaah   Telugu
#
#    ProductionCompany
# 20  Arka Media Works
